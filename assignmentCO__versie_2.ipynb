# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
CO2_data = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_carbon_dioxide_emissions")
FD = CO2_data[1]
FD.columns = ["Country", "MTCO_1990", "MTCO_2005", "MTCO_2017", "2017_world_%", "2017_perc_change","Per_land_area", "Per_capita", "incl_LUCF", "Excl_LUCF"]
FD = FD[ FD["Country"].str.contains ("World|European Union")== False]

FD
# Out:
#             Country  MTCO_1990  MTCO_2005  MTCO_2017 2017_world_%  \
# 3       Afghanistan      2.546      1.063     11.422        0.03%
# 4           Albania      6.583      4.196      5.026        0.01%
# 5           Algeria     65.677     98.197    159.929        0.43%
# 6            Angola      5.851     15.975     30.876        0.08%
# 7          Anguilla      0.006      0.014      0.028        0.00%
# ..              ...        ...        ...        ...          ...
# 207         Vietnam     20.182     99.231    218.729        0.59%
# 208  Western Sahara      0.144      0.227      0.276        0.00%
# 209           Yemen      6.887     21.768     12.503        0.03%
# 210          Zambia      2.955      2.457      4.967        0.01%
# 211        Zimbabwe     17.178     11.388     12.087        0.03%
#
#     2017_perc_change  Per_land_area  Per_capita incl_LUCF Excl_LUCF
# 3             348.6%           18.0         0.3      7.59      7.44
# ...

# %%
Large_countries = FD.nlargest(5,["MTCO_1990","MTCO_2005","MTCO_2017"])
Large_countries
# Out:
#            Country  MTCO_1990  MTCO_2005  MTCO_2017 2017_world_%  \
# 202  United States   5085.897   5971.571   5107.393       13.77%
# 42           China   2397.048   6263.064  10877.218       29.34%
# 158         Russia   2378.921   1733.950   1764.866        4.76%
# 102          Japan   1149.400   1276.863   1320.776        3.56%
# 77         Germany   1018.097    837.284    796.529        2.15%
#
#     2017_perc_change  Per_land_area  Per_capita incl_LUCF Excl_LUCF
# 202             0.4%          519.0        15.7   4749.57   4981.30
# 42            353.8%         1133.0         7.7   9663.36  10313.46
# 158           -25.8%          103.0        12.3   1049.05   1607.55
# 102            14.9%         3494.0        10.4   1074.08   1106.15
# 77            -21.8%         2230.0         9.7    680.06    709.54

# %%
Large_countries = FD.nlargest(5,["MTCO_1990","MTCO_2005","MTCO_2017"])
Large_countries.head(5)
from tables.table import Column
fig, ax = plt.subplots()
fig = plt.figure
years = Large_countries.columns[1:4]
for index,row in Large_countries.iterrows():
  plt.plot(years,row[1:4], label = row[0])

plt.title ("5 biggest CO2 Producers")
#plt.xlabel ("1990", "2005" ,"2017")
plt.ylabel ("CO2 Emiission in MT")
plt.grid()
#plt.show()
ax.legend()
